# %% [markdown]
# <h3><center>
#     Covid 19 Vaccination ANALYSIS

# %% [markdown]
# <h4> PROBLEMS

# %% [markdown]
# After looking at the data, We can start analyzing and ask some question from from the data set.
#
#
# - Which country is top in the vaccination drive?
# - Types of vaccination
# - Active Vacinated and People Cured?

# %% [markdown]
# _____

# %% [markdown]
# <h4> IMPORTING LIBRARIES

# %%
#data Cleaning
import pandas as pd


#data visualization
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df = pd.read_csv("E:\\Data Analysis Study\\Project\\Pandas Vaccination Analysis\\archive\\country_vaccinations.csv")

# %%
df.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3619 entries, 0 to 3618
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              3619 non-null   object
#  1   iso_code                             3343 non-null   object
#  2   date                                 3619 non-null   object
#  3   total_vaccinations                   2393 non-null   float64
#  4   people_vaccinated                    1981 non-null   float64
#  5   people_fully_vaccinated              1324 non-null   float64
#  6   daily_vaccinations_raw               2019 non-null   float64
#  7   daily_vaccinations                   3483 non-null   float64
#  8   total_vaccinations_per_hundred       2393 non-null   float64
#  9   people_vaccinated_per_hundred        1981 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1324 non-null   float64
# ...

# %%
pwd
# Out:
# 'C:\\Users\\Red'

# %%
df.shape
# Out:
# (3619, 15)

# %%
df.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# country                                   0
# iso_code                                276
# date                                      0
# total_vaccinations                     1226
# people_vaccinated                      1638
# people_fully_vaccinated                2295
# daily_vaccinations_raw                 1600
# daily_vaccinations                      136
# total_vaccinations_per_hundred         1226
# people_vaccinated_per_hundred          1638
# people_fully_vaccinated_per_hundred    2295
# daily_vaccinations_per_million          136
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        2.393000e+03       1.981000e+03             1.324000e+03
# mean         1.521028e+06       1.269657e+06             3.888861e+05
# std          5.038410e+06       4.148487e+06             1.476223e+06
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          2.989300e+04       2.702000e+04             8.366000e+03
# 50%          1.917820e+05       1.694400e+05             3.395450e+04
# 75%          7.689500e+05       6.324390e+05             1.947678e+05
# max          6.128950e+07       4.280960e+07             1.789567e+07
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            2.019000e+03        3.483000e+03
# mean             7.453608e+04        5.754796e+04
# std              2.065813e+05        1.784900e+05
# min             -5.001200e+04        1.000000e+00
# 25%              2.021000e+03        1.207500e+03
# ...

# %% [markdown]
# <h4> DATA CLEANING

# %%
df.fillna(value = 0, inplace = True)
df.total_vaccinations = df.total_vaccinations.astype(int)
df.people_vaccinated = df.people_vaccinated.astype(int)
df.people_fully_vaccinated = df.people_fully_vaccinated.astype(int)
df.daily_vaccinations_raw = df.daily_vaccinations_raw.astype(int)
df.total_vaccinations_per_hundred = df.total_vaccinations_per_hundred.astype(int)
df.people_vaccinated_per_hundred = df.people_vaccinated_per_hundred.astype(int)
df.people_fully_vaccinated_per_hundred = df.people_fully_vaccinated_per_hundred.astype(int)
df.daily_vaccinations_per_million = df.daily_vaccinations_per_million.astype(int)

# %%
df.drop(['source_website'], axis = 1, inplace = True)

# %%
date = df.date.str.split('-', expand=True)
date
# Out:
#          0   1   2
# 0     2021  01  10
# 1     2021  01  11
# 2     2021  01  12
# 3     2021  01  13
# 4     2021  01  14
# ...    ...  ..  ..
# 3614  2021  02  15
# 3615  2021  02  16
# 3616  2021  02  17
# 3617  2021  02  18
# 3618  2021  02  19
#
# [3619 rows x 3 columns]

# %%
df['year'] = date[0]
df['month'] = date[1]
df['day'] = date[2]

df.year = pd.to_numeric(df.year)
df.month = pd.to_numeric(df.month)
df.day = pd.to_numeric(df.day)

# %%
df.date = pd.to_datetime(df.date)
df.head()
# Out:
#    country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB 2021-01-10                   0                  0
# 1  Albania      ALB 2021-01-11                   0                  0
# 2  Albania      ALB 2021-01-12                 128                128
# 3  Albania      ALB 2021-01-13                 188                188
# 4  Albania      ALB 2021-01-14                 266                266
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                        0                       0                 0.0
# 1                        0                       0                64.0
# 2                        0                       0                64.0
# 3                        0                      60                63.0
# 4                        0                      78                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# --------------------

# %% [markdown]
# <h4>EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Top 10 countries on vaccination drive?

# %%
Tcountry = df.groupby(['country']).sum().reset_index()
Tcountry
# Out:
#                      country  total_vaccinations  people_vaccinated  \
# 0                    Albania               10089               8428
# 1                    Algeria               75030                  0
# 2                    Andorra                4525               2903
# 3                   Anguilla                1341               1341
# 4                  Argentina            13849614            9221917
# ..                       ...                 ...                ...
# 93  Turks and Caicos Islands                6433               6433
# 94      United Arab Emirates           136222806             836568
# 95            United Kingdom           399558369          379335816
# 96             United States          1259575637          976813730
# 97                     Wales            17726517           17578650
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      1661                    1769              1931.0
# ...

# %%
TDA = df.groupby(['country']).sum()["people_vaccinated"].tail(20).sort_values(ascending=False).reset_index()
TDA
# Out:
#                      country  people_vaccinated
# 0              United States        976813730.0
# 1             United Kingdom        379335816.0
# 2                     Turkey         37643449.0
# 3                      Spain         35707921.0
# 4                   Scotland         27781549.0
# 5                      Wales         17578650.0
# 6                     Serbia          7599195.0
# 7                   Slovakia          5913686.0
# 8                     Russia          4080500.0
# 9                     Sweden          2869045.0
# 10                  Slovenia          2479100.0
# 11               Switzerland          1791236.0
# 12      United Arab Emirates           836568.0
# 13                 Singapore           762600.0
# 14                Seychelles           664625.0
# 15              South Africa            19198.0
# 16  Turks and Caicos Islands             6433.0
# 17                 Sri Lanka                0.0
# 18              Saudi Arabia                0.0
# ...

# %%
plt.figure(figsize=(16,7))
plt.bar(TDA.country,TDA.people_vaccinated)
plt.xticks(rotation= 'vertical');
plt.xlabel('Countries')
plt.ylabel('Total People Vaccinated');

# %% [markdown]
# Type of Vaccination?

# %%
TOV = df.groupby(["vaccines"]).sum()['daily_vaccinations_per_million'].sort_values(ascending= False).reset_index()
TOV
# Out:
#                                              vaccines  \
# 0                                     Pfizer/BioNTech
# 1                 Oxford/AstraZeneca, Pfizer/BioNTech
# 2                            Moderna, Pfizer/BioNTech
# 3        Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 4               Oxford/AstraZeneca, Sinopharm/Beijing
# 5   Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm...
# 6                                  Oxford/AstraZeneca
# 7                            Pfizer/BioNTech, Sinovac
# 8                  Pfizer/BioNTech, Sinopharm/Beijing
# 9       Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V
# 10                                            Sinovac
# 11                                          Sputnik V
# 12                        Oxford/AstraZeneca, Sinovac
# 13        Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac
# 14                                  Sinopharm/Beijing
# 15                        Covaxin, Oxford/AstraZeneca
# ...

# %%
plt.figure(figsize=(12,6))
plt.bar(TOV.vaccines,TOV.daily_vaccinations_per_million);
plt.xticks(rotation = '280');

# %% [markdown]
# Active Vacinated and People Cured?

# %%
df.head(2)
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            22.0
#
#           vaccines         source_name
# 0  Pfizer/BioNTech  Ministry of Health
# ...

# %%
df.groupby(['country']).sum()['total_vaccinations_per_hundred'].sort_values(ascending = False).reset_index()
# Out:
#                  country  total_vaccinations_per_hundred
# 0                 Israel                         2384.97
# 1              Gibraltar                         1731.86
# 2   United Arab Emirates                         1377.32
# 3             Seychelles                          782.39
# 4                England                          608.49
# ..                   ...                             ...
# 93             Mauritius                            0.02
# 94                  Iran                            0.01
# 95    Dominican Republic                            0.00
# 96                 Egypt                            0.00
# 97                 Japan                            0.00
#
# [98 rows x 2 columns]
